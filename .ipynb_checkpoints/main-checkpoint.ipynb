# %%
from pandas import DataFrame
import pandas as pd
import numpy as np

# %%
data = pd.read_table('./docs/export_low_small.txt')
# Out:
# /home/richie/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# 展示前 10 行数据
data[:10]
# Out:
#             3   Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0   Frequency          Phi   -3.141593   -3.106686   -3.071779   -3.036873
# 1  1000000000            0    0.358900    0.337200    0.315900    0.294600
# 2  1000000000  0.034906585    0.351200    0.330200    0.309600    0.288900
# 3  1000000000   0.06981317    0.343100    0.322800    0.303000    0.282900
# 4  1000000000  0.104719755    0.334500    0.315100    0.296000    0.276700
# 5  1000000000   0.13962634    0.325600    0.307000    0.288700    0.270200
# 6  1000000000  0.174532925    0.316200    0.298500    0.281200    0.263500
# 7  1000000000   0.20943951    0.306500    0.289700    0.273200    0.256500
# 8  1000000000  0.244346095    0.296400    0.280600    0.265000    0.249200
# 9  1000000000   0.27925268    0.285900    0.271100    0.256500    0.241700
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9      ...       Unnamed: 173  \
# 0   -3.001966    -2.96706   -2.932153   -2.897247      ...           2.827433
# 1    0.272400     0.24870    0.223100    0.195300      ...          -0.594500
# 2    0.267300     0.24420    0.219300    0.192100      ...          -0.579900
# 3    0.262000     0.23960    0.215400    0.188900      ...          -0.564600
# 4    0.256500     0.23490    0.211500    0.185800      ...          -0.548500
# 5    0.250900     0.23010    0.207500    0.182800      ...          -0.531800
# 6    0.245000     0.22510    0.203400    0.179700      ...          -0.514400
# 7    0.238900     0.22000    0.199300    0.176600      ...          -0.496400
# 8    0.232600     0.21470    0.195000    0.173500      ...          -0.477900
# 9    0.226100     0.20920    0.190700    0.170300      ...          -0.458900
#
#    Unnamed: 174  Unnamed: 175  Unnamed: 176  Unnamed: 177  Unnamed: 178  \
# 0       2.86234      2.897247      2.932153       2.96706      3.001966
# 1      -0.56980     -0.542800     -0.514700      -0.48620     -0.458200
# 2      -0.55570     -0.529500     -0.502100      -0.47440     -0.447200
# 3      -0.54100     -0.515400     -0.488800      -0.46200     -0.435700
# 4      -0.52550     -0.500700     -0.474900      -0.44900     -0.423600
# 5      -0.50940     -0.485300     -0.460400      -0.43540     -0.411000
# 6      -0.49270     -0.469400     -0.445300      -0.42120     -0.397800
# 7      -0.47540     -0.452900     -0.429700      -0.40660     -0.384100
# 8      -0.45760     -0.435900     -0.413700      -0.39150     -0.370000
# 9      -0.43930     -0.418500     -0.397100      -0.37590     -0.355500
#
#    Unnamed: 179  Unnamed: 180  Unnamed: 181  Unnamed: 182
# 0      3.036873      3.071779      3.106686      3.141593
# 1     -0.431200     -0.405700     -0.381600     -0.358900
# 2     -0.421100     -0.396400     -0.373100     -0.351200
# 3     -0.410500     -0.386600     -0.364200     -0.343100
# 4     -0.399300     -0.376400     -0.354800     -0.334500
# 5     -0.387600     -0.365600     -0.345000     -0.325600
# 6     -0.375400     -0.354400     -0.334700     -0.316200
# 7     -0.362800     -0.342700     -0.324000     -0.306500
# 8     -0.349700     -0.330700     -0.313000     -0.296400
# 9     -0.336200     -0.318200     -0.301500     -0.285900
#
# [10 rows x 183 columns]

# %%
# 连接 mongodb
from pymongo import MongoClient
conn = MongoClient('localhost', 27017)
db = conn.mydb
my_set = db.test_set

# %%
# 向mongodb插入数据
tobeInser = data.values[1:,:]
totalNum = tobeInser.shape[0]
for i in range(totalNum):
    my_set.insert({"freq":int(tobeInser[i,0]),
                   "phi":float(tobeInser[i,1]),
                   "vals":tobeInser[i,2:].astype(np.float64).tolist() })
# Out:
# /home/richie/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.

# %%
from bson.code import Code
# mapreduce 查询
def mapreduce(freq_input, phi_input):
    # map 函数
    mapfun = Code("""
                    function(){
                        emit({freqs:this.freq, phis:this.phi}, {values: this.vals});
                    }
                """)

    # reduce 函数
    reducefun = Code("""
                    function(key, value) {
                        var res = { values: value };
                        return res;
                    }
                """)
    result = my_set.map_reduce(mapfun, reducefun, query={"freq":freq_input, "phi":phi_input},out="test")
    return result

# %%
    
# 查询参数
freq_input = 1000000000
phi_input = 0

# mapreduce 查询
result = mapreduce(freq_input, phi_input)
result_num = result.count()
res = [doc['value']['values'] for doc in result.find()][0]

# %%
# 将 theta 转换为度数
theta = data.values[0][2:].astype(np.float64) * 180 / np.pi
# 频率的所有取值
freq = list(set(data.values[1:, 0].astype(np.int64)))
# phi的所有取值
# 将 phi 转换为度数
phi = list(set(data.values[1:, 1].astype(np.float64) * 180 / np.pi))

# %%
# 画图
from pyecharts import Line
attr = np.round(theta,2)
v1 = res
line = Line("theta角度vs电场作图")
line.add("Electrial Field1", attr, v1, is_smooth=True,
         xaxis_name = 'Theta(degree)', yaxis_name = 'Electrical field (V/m)',
         xaxis_name_gap = 30, yaxis_name_gap = 40)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="36c37b48bbd5420c9e90af4a35dafe43" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_36c37b48bbd5420c9e90af4a35dafe43 = echarts.init(document.getElementById('36c37b48bbd5420c9e90af4a35dafe43'), 'light', {renderer: 'canvas'});
#
# var option_36c37b48bbd5420c9e90af4a35dafe43 = {
#     "title": [
#         {
#             "text": "theta\u89d2\u5ea6vs\u7535\u573a\u4f5c\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6477031,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "Electrial Field1",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 0.358900011,
#                 0.337199986,
#                 0.315899998,
#                 0.29460001,
#                 0.272399992,
#                 0.248699993,
#                 0.223100007,
#                 0.195299998,
#                 0.165199995,
#                 0.1329,
#                 0.098970003,
#                 0.06413000099999999,
#                 0.029309999,
#                 -0.0044,
#                 -0.035840001,
#                 -0.063859999,
#                 -0.08743,
#                 -0.105700001,
#                 -0.118000001,
#                 -0.12420000099999999,
#                 -0.124300003,
#                 -0.11860000300000001,
#                 -0.10800000300000001,
#                 -0.09331999699999999,
#                 -0.075850002,
#                 -0.056869999000000004,
#                 -0.03768,
#                 -0.01952,
#                 -0.0034490000000000002,
#                 0.009701000000000001,
#                 0.019400001,
#                 0.025450001,
#                 0.027969999,
#                 0.027389998999999998,
#                 0.02441,
#                 0.019920001,
#                 0.01492,
#                 0.01048,
#                 0.007579000000000001,
#                 0.007090000000000001,
#                 0.009692000000000001,
#                 0.015830001,
#                 0.02568,
#                 0.039159998,
#                 0.055969998,
#                 0.075580001,
#                 0.09734000300000001,
#                 0.12049999800000001,
#                 0.144299999,
#                 0.16809999899999997,
#                 0.191300005,
#                 0.213499993,
#                 0.234400004,
#                 0.254000008,
#                 0.272500008,
#                 0.289999992,
#                 0.307099998,
#                 0.324200004,
#                 0.341800004,
#                 0.360300004,
#                 0.379999995,
#                 0.401199996,
#                 0.423900008,
#                 0.44789999700000005,
#                 0.47299999,
#                 0.49869999299999995,
#                 0.5245000120000001,
#                 0.549799979,
#                 0.573800027,
#                 0.595899999,
#                 0.61559999,
#                 0.632399976,
#                 0.645799994,
#                 0.655799985,
#                 0.662199974,
#                 0.665099978,
#                 0.664600015,
#                 0.66109997,
#                 0.654799998,
#                 0.646200001,
#                 0.635399997,
#                 0.622799993,
#                 0.60860002,
#                 0.592999995,
#                 0.575999975,
#                 0.5576999779999999,
#                 0.538100004,
#                 0.51700002,
#                 0.494500011,
#                 0.47040000600000004,
#                 0.44470000299999995,
#                 -0.41740000200000005,
#                 -0.388599992,
#                 -0.35839998700000003,
#                 -0.32710000899999997,
#                 -0.294800013,
#                 -0.261799991,
#                 -0.228400007,
#                 -0.19490000600000001,
#                 -0.161699995,
#                 -0.128800005,
#                 -0.09653999699999999,
#                 -0.065090001,
#                 -0.03455,
#                 -0.005012,
#                 0.023469999,
#                 0.050840002,
#                 0.077069998,
#                 0.1021,
#                 0.125799999,
#                 0.148200005,
#                 0.16910000100000003,
#                 0.188299999,
#                 0.205699995,
#                 0.22110000300000002,
#                 0.234400004,
#                 0.24539999699999998,
#                 0.254099995,
#                 0.26030001,
#                 0.26429998899999996,
#                 0.26589998600000003,
#                 0.265399992,
#                 0.262899995,
#                 0.25859999699999997,
#                 0.252600014,
#                 0.245199993,
#                 0.236599997,
#                 0.226799995,
#                 0.215800002,
#                 0.20389999399999997,
#                 0.19079999600000003,
#                 0.176499993,
#                 0.160899997,
#                 0.143900007,
#                 0.125499994,
#                 0.105599999,
#                 0.084129997,
#                 0.061209999,
#                 0.036959998,
#                 0.01158,
#                 -0.01468,
#                 -0.041540001,
#                 -0.068700001,
#                 -0.09587000300000001,
#                 -0.1228,
#                 -0.149399996,
#                 -0.175400004,
#                 -0.201000005,
#                 -0.22619999899999998,
#                 -0.251100004,
#                 -0.27610001,
#                 -0.301400006,
#                 -0.327199996,
#                 -0.353899986,
#                 -0.381500006,
#                 -0.410100013,
#                 -0.439599991,
#                 -0.469599992,
#                 -0.49970001,
#                 -0.529299974,
#                 -0.5576000210000001,
#                 -0.583899975,
#                 -0.60710001,
#                 -0.6266000270000001,
#                 -0.641499996,
#                 -0.651199996,
#                 -0.6553000210000001,
#                 -0.653699994,
#                 -0.6463000179999999,
#                 -0.633599997,
#                 -0.616100013,
#                 -0.594500005,
#                 -0.569800019,
#                 -0.542800009,
#                 -0.514699996,
#                 -0.486200005,
#                 -0.458200008,
#                 -0.431199998,
#                 -0.40569999799999995,
#                 -0.38159999299999997,
#                 -0.358900011
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
